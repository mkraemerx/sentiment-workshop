# %%
import pandas as pd
import spacy
import re
import random

# %% [markdown]
# ### Read data

# %%
df_trn = pd.read_csv('germeval2018.training.txt', sep='\t', header=None, names=['text', 'bin', 'detail'])
print(df_trn.head())
df_trn['bin'].value_counts()
# Out:
#                                                 text      bin  detail
# 0  @corinnamilborn Liebe Corinna, wir würden dich...    OTHER   OTHER
# 1  @Martin28a Sie haben ja auch Recht. Unser Twee...    OTHER   OTHER
# 2  @ahrens_theo fröhlicher gruß aus der schönsten...    OTHER   OTHER
# 3  @dushanwegner Amis hätten alles und jeden gewä...    OTHER   OTHER
# 4  @spdde kein verläßlicher Verhandlungspartner. ...  OFFENSE  INSULT
# OTHER      3321
# OFFENSE    1688
# Name: bin, dtype: int64

# %% [markdown]
# The data is given as UTF-8 text and is quite balanced (1/3 of rows is offensive)

# %%
# generate a list of samples

#idx = [3, 27, 65]
idx = random.sample(range(len(df_trn)), 10)

# %%
# set up spacy
nlp = spacy.load('de')

for i in idx:
    sample = df_trn['text'][i]
    print(f'\n---\nsample: {sample}')
    # replace twitter handles
    sample_opt = sample
    #sample_opt = re.sub('@(\S+)', lambda m: m.group(1).capitalize(), sample)
    #sample_opt = re.sub('#(\S+)', lambda m: m.group(1), sample)
    #if sample is not sample_opt:
    #    print(f'optimized sample: {sample_opt}')
    print('')    
    doc = nlp(sample_opt)
    for token in doc:
        print("{0:<20}\t{1:20}\t{2:4}\t{3:5}\t{4}".format(token.text, token.lemma_, token.pos_, token.tag_, token.has_vector))
# Out:
# ---
# sample: @raschie2 Kandidieren sie doch für den Bundestag, werden gewählt und bringen ein solches Gesetz ein..
#
# @raschie2           	@raschie2           	PROPN	NE   	True
# Kandidieren         	Kandidieren         	VERB	VVFIN	True
# sie                 	ich                 	PRON	PPER 	True
# doch                	doch                	ADV 	ADV  	True
# für                 	für                 	ADP 	APPR 	True
# den                 	der                 	DET 	ART  	True
# Bundestag           	Bundestag           	NOUN	NN   	True
# ,                   	,                   	PUNCT	$,   	True
# werden              	werden              	AUX 	VAFIN	True
# gewählt             	wählen              	VERB	VVPP 	True
# und                 	und                 	CONJ	KON  	True
# bringen             	bringen             	VERB	VVFIN	True
# ein                 	einen               	DET 	ART  	True
# solches             	solch               	DET 	PIAT 	True
# Gesetz              	Gesetz              	NOUN	NN   	True
# ein                 	einen               	PART	PTKVZ	True
# ..                  	..                  	PUNCT	$.   	True
#
# ---
# sample: @polizeiberlin Das ist sehr erfreulich und eine vernünftige Entscheidung.
#
# @polizeiberlin      	@polizeiberlin      	AUX 	VAFIN	True
# Das                 	Das                 	PRON	PDS  	True
# ist                 	sein                	AUX 	VAFIN	True
# sehr                	sehr                	ADV 	ADV  	True
# erfreulich          	erfreulich          	ADJ 	ADJD 	True
# und                 	und                 	CONJ	KON  	True
# eine                	einen               	DET 	ART  	True
# vernünftige         	vernünftig          	ADJ 	ADJA 	True
# Entscheidung        	Entscheidung        	NOUN	NN   	True
# .                   	.                   	PUNCT	$.   	True
#
# ---
# sample: @troll_putin @SJW_MadBunny @machtjanix23 @Steffmann45 @petpanther0 @mastermikeg @Norbinator2403 @ennof_ @AthinaMala @NancyPeggyMandy @info2099 @lifetrend @ThomasGBauer @SchmiddieMaik @charlie_silve @NoHerrman @willjrosenblatt @feldenfrizz @nasanasal @_macmike @ellibisathide @MD_Franz Ich kann jede Minute im Leben nur einmal nutzen - an Vollpfosten, die nicht einmal interessant sind, verschwende ich keine Zeit mehr. Für interessante Menschen gebe ich gerne Zeit.
#
# @troll_putin        	@troll_putin        	NOUN	NN   	True
# @SJW_MadBunny       	@SJW_MadBunny       	PROPN	NE   	True
# @machtjanix23       	@machtjanix23       	PROPN	NE   	True
# @Steffmann45        	@Steffmann45        	PROPN	NE   	True
# @petpanther0        	@petpanther0        	PROPN	NE   	True
# @mastermikeg        	@mastermikeg        	ADJ 	ADJD 	True
# @Norbinator2403     	@Norbinator2403     	PROPN	NE   	True
# @ennof              	@ennof              	PROPN	NE   	True
# _                   	_                   	X   	XY   	True
# @AthinaMala         	@AthinaMala         	PROPN	NE   	True
# @NancyPeggyMandy    	@NancyPeggyMandy    	PROPN	NE   	True
# @info2099           	@info2099           	PROPN	NE   	True
# @lifetrend          	@lifetrend          	ADJ 	ADJD 	True
# @ThomasGBauer       	@ThomasGBauer       	ADV 	ADV  	True
# @SchmiddieMaik      	@SchmiddieMaik      	ADV 	ADV  	True
# @charlie_silve      	@charlie_silve      	PROPN	NE   	True
# @NoHerrman          	@NoHerrman          	PROPN	NE   	True
# @willjrosenblatt    	@willjrosenblatt    	NOUN	NN   	True
# @feldenfrizz        	@feldenfrizz        	NOUN	NN   	True
# @nasanasal          	@nasanasal          	NOUN	NN   	True
# @_macmike           	@_macmike           	PROPN	NE   	True
# @ellibisathide      	@ellibisathide      	PROPN	NE   	True
# @MD_Franz           	@MD_Franz           	PROPN	NE   	True
# Ich                 	Ich                 	PRON	PPER 	True
# kann                	können              	VERB	VMFIN	True
# jede                	jed                 	DET 	PIAT 	True
# Minute              	Minute              	NOUN	NN   	True
# im                  	im                  	ADP 	APPRART	True
# Leben               	Leben               	NOUN	NN   	True
# nur                 	nur                 	ADV 	ADV  	True
# einmal              	einmal              	ADV 	ADV  	True
# nutzen              	nutzen              	VERB	VVINF	True
# -                   	-                   	PUNCT	$(   	True
# an                  	an                  	ADP 	APPR 	True
# Vollpfosten         	Vollpfosten         	NOUN	NN   	True
# ,                   	,                   	PUNCT	$,   	True
# die                 	der                 	PRON	PRELS	True
# nicht               	nicht               	PART	PTKNEG	True
# einmal              	einmal              	ADV 	ADV  	True
# interessant         	interessant         	ADJ 	ADJD 	True
# sind                	sein                	AUX 	VAFIN	True
# ,                   	,                   	PUNCT	$,   	True
# verschwende         	verschwenden        	VERB	VVFIN	True
# ich                 	ich                 	PRON	PPER 	True
# keine               	kein                	DET 	PIAT 	True
# Zeit                	Zeit                	NOUN	NN   	True
# mehr                	mehr                	ADV 	ADV  	True
# .                   	.                   	PUNCT	$.   	True
# Für                 	Für                 	ADP 	APPR 	True
# interessante        	interessante        	ADJ 	ADJA 	True
# Menschen            	Mensch              	NOUN	NN   	True
# gebe                	geben               	VERB	VVFIN	True
# ich                 	ich                 	PRON	PPER 	True
# gerne               	gerne               	ADV 	ADV  	True
# Zeit                	Zeit                	NOUN	NN   	True
# .                   	.                   	PUNCT	$.   	True
#
# ---
# sample: @aotto1968_2 FDP Wähler haben sich noch nicht AfD wählen trauen.
#
# @aotto1968_2        	@aotto1968_2        	X   	XY   	True
# FDP                 	FDP                 	PROPN	NE   	True
# Wähler              	Wähler              	NOUN	NN   	True
# haben               	haben               	AUX 	VAFIN	True
# sich                	sich                	PRON	PRF  	True
# noch                	noch                	ADV 	ADV  	True
# nicht               	nicht               	PART	PTKNEG	True
# AfD                 	AfD                 	PROPN	NE   	True
# wählen              	wählen              	VERB	VVINF	True
# trauen              	trauen              	VERB	VVINF	True
# .                   	.                   	PUNCT	$.   	True
#
# ---
# sample: @WEBDE_News Bitte etwas mehr Disziplin, die Gäste nicht ständig unterbrechen. |LBR| Wo sind wir denn? Blödes -beantworten sie meine Frage.
#
# @WEBDE_News         	@WEBDE_News         	VERB	VVFIN	True
# Bitte               	bitten              	ADV 	ADV  	True
# etwas               	etwas               	ADV 	ADV  	True
# mehr                	mehr                	DET 	PIAT 	True
# Disziplin           	Disziplin           	NOUN	NN   	True
# ,                   	,                   	PUNCT	$,   	True
# die                 	der                 	DET 	ART  	True
# Gäste               	Gast                	NOUN	NN   	True
# nicht               	nicht               	PART	PTKNEG	True
# ständig             	ständig             	ADJ 	ADJD 	True
# unterbrechen        	unterbrechen        	VERB	VVINF	True
# .                   	.                   	PUNCT	$.   	True
# |LBR|               	|LBR|               	NOUN	NN   	True
# Wo                  	Wo                  	ADV 	PWAV 	True
# sind                	sein                	AUX 	VAFIN	True
# wir                 	ich                 	PRON	PPER 	True
# denn                	denn                	ADV 	ADV  	True
# ?                   	?                   	PUNCT	$.   	True
# Blödes              	Blödes              	PROPN	NE   	True
# -beantworten        	-beantworten        	NOUN	NN   	True
# sie                 	ich                 	PRON	PPER 	True
# meine               	meinen              	DET 	PPOSAT	True
# Frage               	Frage               	NOUN	NN   	True
# .                   	.                   	PUNCT	$.   	True
#
# ---
# sample: Reagan sah einst "The day after", schiss sich in d. Hose u. beendete Provokationen ( die u.a. zum Abschuss d. korean. PassagierJets führten)
#
# Reagan              	Reagan              	PROPN	NE   	True
# sah                 	sehen               	VERB	VVFIN	True
# einst               	einen               	ADV 	ADV  	True
# "                   	"                   	PUNCT	$.   	True
# The                 	The                 	PROPN	NE   	True
# day                 	day                 	PROPN	NE   	True
# after               	after               	ADJ 	ADJA 	True
# "                   	"                   	PUNCT	$.   	True
# ,                   	,                   	PUNCT	$,   	True
# schiss              	schiss              	VERB	VVFIN	True
# sich                	sich                	PRON	PRF  	True
# in                  	in                  	ADP 	APPR 	True
# d.                  	d.                  	DET 	ART  	True
# Hose                	Hose                	NOUN	NN   	True
# u.                  	u.                  	ADP 	APPR 	True
# beendete            	beenden             	ADJ 	ADJA 	True
# Provokationen       	Provokation         	NOUN	NN   	True
# (                   	(                   	PUNCT	$(   	True
# die                 	der                 	PRON	PRELS	True
# u.a.                	u.a.                	NOUN	NN   	True
# zum                 	zum                 	ADP 	APPRART	True
# Abschuss            	Abschuss            	NOUN	NN   	True
# d.                  	d.                  	PRON	PDS  	True
# korean              	korean              	VERB	VVFIN	True
# .                   	.                   	PUNCT	$.   	True
# PassagierJets       	PassagierJets       	PROPN	NE   	True
# führten             	führen              	VERB	VVFIN	True
# )                   	)                   	PUNCT	$(   	True
#
# ---
# sample: Normale Beziehungen zwischen Russland und Türkei .. ja. |LBR| Aber Freundschaft nur mit Deutschland. Weg mit den Sanktionen.
#
# Normale             	normal              	ADJ 	ADJA 	True
# Beziehungen         	Beziehung           	NOUN	NN   	True
# zwischen            	zwischen            	ADP 	APPR 	True
# Russland            	Russland            	PROPN	NE   	True
# und                 	und                 	CONJ	KON  	True
# Türkei              	Türkei              	PROPN	NE   	True
# ..                  	..                  	PUNCT	$.   	True
# ja                  	ja                  	ADV 	ADV  	True
# .                   	.                   	PUNCT	$.   	True
# |LBR|               	|LBR|               	NOUN	NN   	True
# Aber                	Aber                	CONJ	KON  	True
# Freundschaft        	Freundschaft        	NOUN	NN   	True
# nur                 	nur                 	ADV 	ADV  	True
# mit                 	mit                 	ADP 	APPR 	True
# Deutschland         	Deutschland         	PROPN	NE   	True
# .                   	.                   	PUNCT	$.   	True
# Weg                 	Weg                 	ADV 	ADV  	True
# mit                 	mit                 	ADP 	APPR 	True
# den                 	der                 	DET 	ART  	True
# Sanktionen          	Sanktion            	NOUN	NN   	True
# .                   	.                   	PUNCT	$.   	True
#
# ---
# sample: @Robert_Braun23 Nö. Wie kommen Sie darauf, dass wir nur im Wahlkampf für Marktwirtschaft werben? Ist uns immer wichtig. TL
#
# @Robert_Braun23     	@Robert_Braun23     	NOUN	NN   	True
# Nö                  	Nö                  	PROPN	NE   	True
# .                   	.                   	PUNCT	$.   	True
# Wie                 	Wie                 	ADV 	PWAV 	True
# kommen              	kommen              	VERB	VVFIN	True
# Sie                 	Sie                 	PRON	PPER 	True
# darauf              	darauf              	ADV 	PROAV	True
# ,                   	,                   	PUNCT	$,   	True
# dass                	dass                	SCONJ	KOUS 	True
# wir                 	ich                 	PRON	PPER 	True
# nur                 	nur                 	ADV 	ADV  	True
# im                  	im                  	ADP 	APPRART	True
# Wahlkampf           	Wahlkampf           	NOUN	NN   	True
# für                 	für                 	ADP 	APPR 	True
# Marktwirtschaft     	Marktwirtschaft     	NOUN	NN   	True
# werben              	werben              	VERB	VVINF	True
# ?                   	?                   	PUNCT	$.   	True
# Ist                 	Ist                 	AUX 	VAFIN	True
# uns                 	sich                	PRON	PPER 	True
# immer               	immer               	ADV 	ADV  	True
# wichtig             	wichtig             	ADJ 	ADJD 	True
# .                   	.                   	PUNCT	$.   	True
# TL                  	TL                  	PROPN	NE   	True
#
# ---
# sample: @blackhawk3423 @hotnakedlove @SteinbachErika Er hatte niemals die Macht das zu verhindern, es war mehr als Warnung an die aber leider zu gehirngewaschene Bevölkerung zu verstehen
#
# @blackhawk3423      	@blackhawk3423      	PROPN	NE   	True
# @hotnakedlove       	@hotnakedlove       	VERB	VVFIN	True
# @SteinbachErika     	@SteinbachErika     	PROPN	NE   	True
# Er                  	Er                  	PRON	PPER 	True
# hatte               	haben               	AUX 	VAFIN	True
# niemals             	niemals             	ADV 	ADV  	True
# die                 	der                 	DET 	ART  	True
# Macht               	Macht               	NOUN	NN   	True
# das                 	der                 	PRON	PDS  	True
# zu                  	zu                  	PART	PTKZU	True
# verhindern          	verhindern          	VERB	VVINF	True
# ,                   	,                   	PUNCT	$,   	True
# es                  	ich                 	PRON	PPER 	True
# war                 	sein                	AUX 	VAFIN	True
# mehr                	mehr                	PRON	PIS  	True
# als                 	als                 	CONJ	KOKOM	True
# Warnung             	Warnung             	NOUN	NN   	True
# an                  	an                  	ADP 	APPR 	True
# die                 	der                 	DET 	ART  	True
# aber                	aber                	ADV 	ADV  	True
# leider              	leider              	ADV 	ADV  	True
# zu                  	zu                  	ADP 	APPR 	True
# gehirngewaschene    	gehirngewaschene    	ADJ 	ADJA 	True
# Bevölkerung         	Bevölkerung         	NOUN	NN   	True
# zu                  	zu                  	PART	PTKZU	True
# verstehen           	verstehen           	VERB	VVINF	True
#
# ---
# sample: @strop_peter 😂😂 in Ihrem Link wird doch auf genau die gleiche Studie zur Familienzusammensetzung Bezug genommen &amp; auch im Übrigen werden dort, wenn es nicht nur um Vermutungen, sondern wirkliche Schätzungen geht, genau die Zahlen aus unserem Ursprungstweet genannt. Besser lesen, Herr Strop.
#
# @strop_peter        	@strop_peter        	NOUN	NN   	True
# 😂                   	😂                   	NOUN	NN   	True
# 😂                   	😂                   	NOUN	NN   	True
# in                  	in                  	ADP 	APPR 	True
# Ihrem               	Ihrem               	DET 	PPOSAT	True
# Link                	Link                	NOUN	NN   	True
# wird                	werden              	AUX 	VAFIN	True
# doch                	doch                	ADV 	ADV  	True
# auf                 	auf                 	ADP 	APPR 	True
# genau               	genau               	ADJ 	ADJD 	True
# die                 	der                 	DET 	ART  	True
# gleiche             	gleich              	ADJ 	ADJA 	True
# Studie              	Studie              	NOUN	NN   	True
# zur                 	zur                 	ADP 	APPRART	True
# Familienzusammensetzung	Familienzusammensetzung	NOUN	NN   	True
# Bezug               	Bezug               	NOUN	NN   	True
# genommen            	nehmen              	VERB	VVPP 	True
# &                   	&                   	CONJ	KON  	True
# amp                 	amp                 	X   	XY   	True
# ;                   	;                   	PUNCT	$.   	True
# auch                	auch                	ADV 	ADV  	True
# im                  	im                  	ADP 	APPRART	True
# Übrigen             	Übrigen             	NOUN	NN   	True
# werden              	werden              	AUX 	VAFIN	True
# dort                	dort                	ADV 	ADV  	True
# ,                   	,                   	PUNCT	$,   	True
# wenn                	wenn                	SCONJ	KOUS 	True
# es                  	ich                 	PRON	PPER 	True
# nicht               	nicht               	PART	PTKNEG	True
# nur                 	nur                 	ADV 	ADV  	True
# um                  	um                  	ADP 	APPR 	True
# Vermutungen         	Vermutung           	NOUN	NN   	True
# ,                   	,                   	PUNCT	$,   	True
# sondern             	sondern             	CONJ	KON  	True
# wirkliche           	wirklich            	ADJ 	ADJA 	True
# Schätzungen         	Schätzung           	NOUN	NN   	True
# geht                	gehen               	VERB	VVFIN	True
# ,                   	,                   	PUNCT	$,   	True
# genau               	genau               	ADJ 	ADJD 	True
# die                 	der                 	DET 	ART  	True
# Zahlen              	Zahl                	NOUN	NN   	True
# aus                 	aus                 	ADP 	APPR 	True
# unserem             	mein                	DET 	PPOSAT	True
# Ursprungstweet      	Ursprungstweet      	NOUN	NN   	True
# genannt             	nennen              	VERB	VVPP 	True
# .                   	.                   	PUNCT	$.   	True
# Besser              	Besser              	ADJ 	ADJD 	True
# lesen               	lesen               	VERB	VVINF	True
# ,                   	,                   	PUNCT	$,   	True
# Herr                	Herr                	NOUN	NN   	True
# Strop               	Strop               	PROPN	NE   	True
# .                   	.                   	PUNCT	$.   	True

# %%
t = "@spdde kein verläßlicher Verhandlungspartner."
t2 = re.sub('@(\S+)', lambda m: '@' + m.group(1).capitalize(), t)
t2
